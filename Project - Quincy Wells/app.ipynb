# %% [markdown]
# # Project/Notebook Goals
#
# ## Assignment:
# * Find active oil/gas wells within a specified radius for a separate list of inactive wells
# * The goal is to determine if the active wells have potentially saved the oil & gas lease pertaining to the inactive well
# * Provide client with Excel Pivot Table showcasing viable active wells that could've saved lease
#
# ## Code Overview
# 1.  Read in geospatial data
#     * Reference Wells - Shapefile of Inactive wells for which company wants to find active wells wtihin 0.5 mile radius
#     * Active Wells - Shapefile of all active wells in counties corresponding to inactive wells
# 2. Prep data by converting CRS for each data set and adding buffer radius to inactive wells
# 3. Geospatially filter active wells within buffer radius for each inactive well
#     * During this step, each returned geodataframe will be stored in a list for concatenation
#     * Also, select fields of the inactive well will be stored to identify list of active wells back to inactive well
# 4. Determine if active well could've saved lease for inactive well
#     * Find minimum first production date for each active well
#         * Wells can have multiple zones, and could contain multiple dates for first production date.  Thus, grouping by each well identifier (API/UWI) is required to ensure we get the earliest date
#     * Based on last production date of inactive well, and earliest first production date of active well within radius, determine if they were in within 1 year of each other
# 5. Export source table for creating Pivot Table in Excel for visualizing results

# %% [markdown]
# # Import Libraries

# %%
import geopandas as gp
import pandas as pd
import numpy as np
import datetime as dt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Read in Data and Preview

# %%
activewells = gp.read_file("zip://Source Data/Active Production/activewells.ZIP")
refwells = gp.read_file("zip://Source Data/Wells to Buffer/bufferwells.ZIP")

activewells.head()
refwells.head()
# Out:
#            APIUWI                       OpAlias             LeaseName  \
# 0  35119237270000              CHER OIL INC LTD           MARK BOYLES
# 1  42479389500000       FLETCHER OPERATING, LLC  WRIGHT-LONG GAS UNIT
# 2  17017336990000   AETHON ENERGY OPERATING LLC      CV RA SU84;CBP 7
# 3  42479387450000  HILCORP ENERGY COMPANY, INC.         PENA-CUEVA GU
# 4  17017336670000     CHANSE ENERGY CORPORATION              FULLER A
#
#     WellNo      County     Reservoir ProdType ProdStatus DrillType       TD  \
# 0        1  PAYNE (OK)  BARTLESVILLE      OIL     ACTIVE         V   4203.0
# 1        2   WEBB (TX)         OLMOS      GAS     ACTIVE         V   7704.0
# 2  001-ALT  CADDO (LA)       CV/HOSS      GAS     ACTIVE         D  10800.0
# 3        1   WEBB (TX)    LOBO CONS.      GAS     ACTIVE         D   9626.0
# 4      092  CADDO (LA)      NACATOSH      OIL     ACTIVE         V   1200.0
#
#    ... BELqBFac BEEURGasMo BEGasEURpr  BEGasBFac  FulLqEURMo  FulLqBFac  \
# 0  ...     2.00      406.0         No       2.00       406.0       2.00
# 1  ...     1.70      399.0         No       2.00       399.0       0.68
# 2  ...     2.00      404.0         No       1.80       404.0       0.97
# 3  ...     1.03      395.0         No       0.96       395.0       0.74
# 4  ...     1.99        0.0         No       0.00       405.0       1.99
#
#    FulGsEURMo  FulGasBFac         OtherNo                    geometry
# 0       406.0        2.00  11911618000000  POINT (-96.89246 36.04677)
# 1       399.0        0.66            5541  POINT (-99.43596 28.09880)
# 2       404.0        0.93          231119  POINT (-93.63690 32.38579)
# 3       395.0        0.34               0  POINT (-99.08561 27.45505)
# 4         0.0        0.00          230912  POINT (-93.89046 32.87569)
#
# [5 rows x 124 columns]
#            APIUWI                        OpAlias                 LeaseName  \
# 0  35119227310000            STACY OPERATING LLC                    LOZIER
# 1  35119226530000            STACY OPERATING LLC             LOZIER (TWIN)
# 2  35119225680000            STACY OPERATING LLC             LOZIER (TWIN)
# 3  35119224510000            STACY OPERATING LLC  DANA-LOZIER (LOZIER #10)
# 4  17113208680000  OLEUM OPERATING COMPANY, L.C.             SAGRERA HEIRS
#
#   WellNo          County       Reservoir ProdType ProdStatus DrillType  \
# 0     13      PAYNE (OK)         MISENER      OIL   INACTIVE         V
# 1     12      PAYNE (OK)          WILCOX      OIL   INACTIVE         V
# 2     11      PAYNE (OK)  MISENER/WILCOX      OIL   INACTIVE         V
# 3     10      PAYNE (OK)  MISENER/WILCOX      OIL    SPUDDED         V
# 4    001  VERMILION (LA)            None      GAS   INACTIVE         D
#
#         TD  ... BELqBFac BEEURGasMo BEGasEURpr  BEGasBFac  FulLqEURMo  \
# 0   3970.0  ...     None       None         No       None        None
# 1   3912.0  ...     None       None         No       None        None
# 2   3906.0  ...     None       None         No       None        None
# 3   3914.0  ...     None       None         No       None        None
# 4  14267.0  ...     None       None       None       None        None
#
#   FulLqBFac  FulGsEURMo FulGasBFac         OtherNo                    geometry
# 0      None        None       None  11905524410000  POINT (-96.84287 36.07648)
# 1      None        None       None  11905524410000  POINT (-96.84289 36.07516)
# 2      None        None       None  11905524410000  POINT (-96.84291 36.07349)
# 3      None        None       None  11905524410000  POINT (-96.84340 36.07517)
# 4      None        None       None          302726  POINT (-92.18802 29.84410)
#
# [5 rows x 124 columns]

# %% [markdown]
# # Prep Data

# %% [markdown]
# ## Convert Geospatial and Geo Dataframes to Same CRS

# %%
activewells.crs
refwells.crs

activewells.to_crs(epsg='26913', inplace=True)
refwells.to_crs(epsg='26913', inplace=True)

activewells.crs
refwells.crs
# Out:
# {'init': 'epsg:4326'}
# {'init': 'epsg:4326'}
# {'init': 'epsg:26913', 'no_defs': True}
# {'init': 'epsg:26913', 'no_defs': True}

# %% [markdown]
# ## Add Buffers to Wells for Geospatial Filtering

# %%
miradius = 0.5
bufferradius = miradius * 1603.34 # converting to miles to meters

refwells['buffer'] = refwells['geometry'].apply(lambda x: x.buffer(bufferradius))

# %% [markdown]
# ### Test Filter

# %%
activewells.loc[activewells.within(refwells.iloc[0]['buffer'])]
# Out:
#                APIUWI              OpAlias      LeaseName WellNo      County  \
# 4050   35119209100000  STACY OPERATING LLC         LOZIER      2  PAYNE (OK)
# 10040  35119225880000  STACY OPERATING LLC   STATE PENNEY      4  PAYNE (OK)
# 11722  35119208510000  STACY OPERATING LLC         LOZIER      1  PAYNE (OK)
# 14974  35119225810000  STACY OPERATING LLC  BUTCHER-JAMES      4  PAYNE (OK)
#
#                         Reservoir ProdType ProdStatus DrillType      TD  ...  \
# 4050       MISENER SAND,MISS LIME      OIL     ACTIVE         V  3804.0  ...
# 10040  RED FORK,PRUE,SKINNER,MISS      OIL     ACTIVE         V  4164.0  ...
# 11722      MISENER SAND,MISS LIME      OIL     ACTIVE         V  3940.0  ...
# 14974                        PRUE      OIL     ACTIVE         V  3910.0  ...
#
#       BELqBFac BEEURGasMo BEGasEURpr  BEGasBFac  FulLqEURMo  FulLqBFac  \
# 4050      1.78       88.0         No       1.85        88.0       1.99
# 10040     0.26      161.0        Yes       1.69       161.0       0.26
# 11722     2.00       88.0         No       0.97        88.0       2.00
# 14974     1.94      166.0        Yes       1.69       166.0       1.94
#
#        FulGsEURMo  FulGasBFac         OtherNo                         geometry
# 4050         88.0        1.51  11905524400000  POINT (1235260.589 4023024.078)
# 10040       161.0        1.69  11902114900371  POINT (1235871.294 4023615.964)
# 11722        88.0        1.51  11905524400000  POINT (1235184.467 4023424.147)
# 14974       166.0        1.69  11902780700000  POINT (1235453.446 4022844.164)
#
# [4 rows x 124 columns]

# %% [markdown]
# # Perform Geospatial Filtering

# %%
listofresults = []

for row in range(0, len(refwells)):
    
    print(f"Searching Active Wells for: {refwells['LeaseName'].iloc[row]}")
    
    buffer = refwells['buffer'].iloc[row]
    hbpwells = activewells.loc[activewells.within(buffer)]
              
          
    #creating dataframe with empty row to store track wells with no active wells found in buffer radius       
    if hbpwells.empty: #if no wells found, dataframe will be empty
          
          hbpwells = pd.DataFrame(columns = activewells.columns) #create dataframe with same columns
          hbpwells = hbpwells.append(pd.Series(), ignore_index=True) #adding empty row so we can assign values
          hbpwells["Reference Inactive API"] = refwells['APIUWI'].iloc[row]  # adding reference well api 
          hbpwells["Reference Inactive Well Name"] = refwells["LeaseName"].iloc[row] + " " + refwells['WellNo'].apply(lambda x: str(x)).iloc[row]
          hbpwells['Reference Inactive Well Last Prod Date'] = refwells['LstPrdDate'].iloc[row]
          hbpwells["County"] = refwells["County"].iloc[row]
          hbpwells["LeaseName"] = f'no active wells found in {miradius} mi radius' # assigining values to all columns except last 2 to mention no wells found
    
    #assiging reference well data to rows to understand which filtered wells are within 0.5 miles of reference well      
    hbpwells["Reference Inactive API"] = refwells['APIUWI'].iloc[row]
    hbpwells["Reference Inactive Well Name"] = refwells["LeaseName"].iloc[row] + " " + refwells['WellNo'].apply(lambda x: str(x)).iloc[row]
    hbpwells['Reference Inactive Well Last Prod Date'] = refwells['LstPrdDate'].iloc[row]
    
    #after geodataframe is created with geospatial filter, append to list for concatenation      
    listofresults.append(hbpwells)

len(listofresults)
# Out:
# Searching Active Wells for: LOZIER
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Searching Active Wells for: LOZIER (TWIN)
# Searching Active Wells for: LOZIER (TWIN)
# Searching Active Wells for: DANA-LOZIER (LOZIER #10)
# Searching Active Wells for: SAGRERA HEIRS
# Searching Active Wells for: TP SU68;WRIGHT
# Searching Active Wells for: WX E RB SU6;KAUFFMAN
# Searching Active Wells for: WX G RB SU6;KAUFFMAN
# Searching Active Wells for: TP SU68;KIRKPATRICK
# Searching Active Wells for: CRIS 8 RB SUA;SAGRERA HEIRS
# Searching Active Wells for: 13400 RC SUA;SAGRERA HEIRS-KTM
# Searching Active Wells for: MARDIS I 1-35
# Searching Active Wells for: MARDIS "I" 1-35
# Searching Active Wells for: GRIFFIN "E"
# Searching Active Wells for: JENKINS "C"
# Searching Active Wells for: THREE "J" RANCH
# Searching Active Wells for: JENKINS
# Searching Active Wells for: HUNTER - KONE
# 18

# %% [markdown]
# # Concat and Modify Results

# %% [markdown]
# ## Concat all GeoSpatial Wells to 1 DataFrame

# %%
hbpwells = pd.concat(listofresults)
hbpwells['Active Well Name & Number'] = hbpwells["LeaseName"] + " " + hbpwells['WellNo'].apply(lambda x: str(x))

# %%
hbpwells.shape
# Out:
# (75, 128)

# %% [markdown]
# ## Getting Minimum Production Date for Each Active Well API

# %%
minstartprod = hbpwells[['APIUWI', 'FstPrdDate']].groupby(['APIUWI']).min()
minstartprod.rename(columns = {"FstPrdDate": 'MinFrstPrdDate'}, inplace = True)


minstartprod.head()
# Out:
#                MinFrstPrdDate
# APIUWI
# 15151010030000     1986-04-01
# 15151217600000     1988-02-01
# 15151218040000     1987-11-01
# 15151218670000     1988-02-01
# 15151218680000     1988-02-01
# 15151218970000     1988-09-01
# 17017324210000     1996-10-01
# 17017324220000     1996-08-01
# 17017358330000     2014-12-01
# 17017360800000     2018-02-01
# 17017360810000     2018-02-01
# 17017360980000     2018-12-01
# 17017361660000     2020-03-01
# 17017361670000     2020-03-01
# 17017362290000     2018-12-01
# 17059239450000     1987-06-01
# 17059239490000     1987-04-01
# 17059239680000     1987-06-01
# 17059239720000     1987-06-01
# 17059240780000     1987-12-01
# 17059248320000     1994-08-01
# 17059248670000     1994-12-01
# 17059249020000     1995-11-01
# 17059249120000     1996-02-01
# 17059249550000     1996-09-01
# 17059249610000     1997-02-01
# 35119010430000     1970-01-01
# 35119200290000     1970-01-01
# 35119208510000     1979-01-01
# 35119209100000     1979-01-01
# 35119225810000     1985-06-01
# 35119225880000     1985-02-01
# 42479340560000     1986-06-01
# 42479341690000     1985-09-01
# 42479390100000     2005-03-01

# %% [markdown]
# ## Left Joining Results with Minimum Production Dates

# %%
hbpwells = pd.merge(left = hbpwells, right = minstartprod, on = 'APIUWI', how = "left")

hbpwells.head()
# Out:
#             APIUWI                       OpAlias  \
# 0   35119209100000           STACY OPERATING LLC
# 1   35119225880000           STACY OPERATING LLC
# 2   35119208510000           STACY OPERATING LLC
# 3   35119225810000           STACY OPERATING LLC
# 4   35119209100000           STACY OPERATING LLC
# 5   35119225880000           STACY OPERATING LLC
# 6   35119208510000           STACY OPERATING LLC
# 7   35119010430000           STACY OPERATING LLC
# 8   35119225810000           STACY OPERATING LLC
# 9   35119209100000           STACY OPERATING LLC
# 10  35119200290000         BAKER OIL AND GAS CO.
# 11  35119208510000           STACY OPERATING LLC
# 12  35119010430000           STACY OPERATING LLC
# 13  35119225810000           STACY OPERATING LLC
# 14  35119209100000           STACY OPERATING LLC
# 15  35119225880000           STACY OPERATING LLC
# 16  35119208510000           STACY OPERATING LLC
# 17  35119010430000           STACY OPERATING LLC
# 18  35119225810000           STACY OPERATING LLC
# 19             NaN                           NaN
# 20  17017324210000                  BHB OIL, INC
# 21  17017360810000            COMSTOCK RESOURCES
# 22  17017361660000            COMSTOCK RESOURCES
# 23  17017360980000            COMSTOCK RESOURCES
# 24  17017360800000            COMSTOCK RESOURCES
# 25  17017358330000                  BHB OIL, INC
# 26  17017361670000            COMSTOCK RESOURCES
# 27  17017362290000            COMSTOCK RESOURCES
# 28  17059240780000         TWC OIL COMPANY, INC.
# 29  17059239490000             WINDHAM OIL CORP.
# ..             ...                           ...
# 45  17059239720000             WINDHAM OIL CORP.
# 46  17059249120000         TWC OIL COMPANY, INC.
# 47  17059239680000             WINDHAM OIL CORP.
# 48  17017324220000                  BHB OIL, INC
# 49  17017360810000            COMSTOCK RESOURCES
# 50  17017360980000            COMSTOCK RESOURCES
# 51  17017360800000            COMSTOCK RESOURCES
# 52  17017358330000                  BHB OIL, INC
# 53  17017362290000            COMSTOCK RESOURCES
# 54             NaN                           NaN
# 55             NaN                           NaN
# 56  15151010030000           DEUTSCH OIL COMPANY
# 57  15151218040000           DEUTSCH OIL COMPANY
# 58  15151218680000          PRATER OIL & GAS OPE
# 59  15151218670000        TRANSPACIFIC OIL CORP.
# 60  15151217600000          PRATER OIL & GAS OPE
# 61  15151218970000         APOLLO ENERGIES, INC.
# 62  15151010030000           DEUTSCH OIL COMPANY
# 63  15151218040000           DEUTSCH OIL COMPANY
# 64  15151218680000          PRATER OIL & GAS OPE
# 65  15151218670000        TRANSPACIFIC OIL CORP.
# 66  15151217600000          PRATER OIL & GAS OPE
# 67  15151218970000         APOLLO ENERGIES, INC.
# 68             NaN                           NaN
# 69             NaN                           NaN
# 70             NaN                           NaN
# 71             NaN                           NaN
# 72  42479341690000  LEWIS PETRO PROPERTIES, INC.
# 73  42479340560000  LEWIS PETRO PROPERTIES, INC.
# 74  42479390100000  LEWIS PETRO PROPERTIES, INC.
#
#                                  LeaseName   WellNo          County  \
# 0                                   LOZIER        2      PAYNE (OK)
# 1                             STATE PENNEY        4      PAYNE (OK)
# 2                                   LOZIER        1      PAYNE (OK)
# 3                            BUTCHER-JAMES        4      PAYNE (OK)
# 4                                   LOZIER        2      PAYNE (OK)
# 5                             STATE PENNEY        4      PAYNE (OK)
# 6                                   LOZIER        1      PAYNE (OK)
# 7                            BUTCHER-JAMES        2      PAYNE (OK)
# 8                            BUTCHER-JAMES        4      PAYNE (OK)
# 9                                   LOZIER        2      PAYNE (OK)
# 10                                 BUTCHER        1      PAYNE (OK)
# 11                                  LOZIER        1      PAYNE (OK)
# 12                           BUTCHER-JAMES        2      PAYNE (OK)
# 13                           BUTCHER-JAMES        4      PAYNE (OK)
# 14                                  LOZIER        2      PAYNE (OK)
# 15                            STATE PENNEY        4      PAYNE (OK)
# 16                                  LOZIER        1      PAYNE (OK)
# 17                           BUTCHER-JAMES        2      PAYNE (OK)
# 18                           BUTCHER-JAMES        4      PAYNE (OK)
# 19  no active wells found in 0.5 mi radius      NaN  VERMILION (LA)
# 20               TP SU68;B J JOHNSON HEIRS  001-ALT      CADDO (LA)
# 21           HA RA SU108;FLOURNOY 29-20 HC  002-ALT      CADDO (LA)
# 22              HA RA SU108;AGURS 29-20 HC  001-ALT      CADDO (LA)
# 23              HA RA SU108;ABNEY 30-19 HC  002-ALT      CADDO (LA)
# 24           HA RA SU108;FLOURNOY 29-20 HC  001-ALT      CADDO (LA)
# 25                   FRED VUB;JOHNSON 32 H      001      CADDO (LA)
# 26              HA RA SU108;AGURS 29-20 HC  002-ALT      CADDO (LA)
# 27              HA RA SU108;ABNEY 30-19 HC  003-ALT      CADDO (LA)
# 28                    WX F RB SU6;KAUFFMAN      006   LA SALLE (LA)
# 29                 WX A2 RF SUA;COON ET AL      006   LA SALLE (LA)
# ..                                     ...      ...             ...
# 45                  WX D2 RF SUA;COON ETAL      009   LA SALLE (LA)
# 46                    WX C RB SU6;KAUFFMAN      003   LA SALLE (LA)
# 47                 WX F1 RF SUA;COON ET AL      008   LA SALLE (LA)
# 48                TP SU68;JOHN ABNEY HEIRS  001-ALT      CADDO (LA)
# 49           HA RA SU108;FLOURNOY 29-20 HC  002-ALT      CADDO (LA)
# 50              HA RA SU108;ABNEY 30-19 HC  002-ALT      CADDO (LA)
# 51           HA RA SU108;FLOURNOY 29-20 HC  001-ALT      CADDO (LA)
# 52                   FRED VUB;JOHNSON 32 H      001      CADDO (LA)
# 53              HA RA SU108;ABNEY 30-19 HC  003-ALT      CADDO (LA)
# 54  no active wells found in 0.5 mi radius      NaN  VERMILION (LA)
# 55  no active wells found in 0.5 mi radius      NaN  VERMILION (LA)
# 56                           MARDIS (1-35)     1-35      PRATT (KS)
# 57                             MARDIS 2-35     2-35      PRATT (KS)
# 58                         MARDIS 'G'CHECK     1-35      PRATT (KS)
# 59                         MARDIS 'F'CHECK     1-35      PRATT (KS)
# 60                             MARDIS UNIT     1-35      PRATT (KS)
# 61                              MONTGOMERY        1      PRATT (KS)
# 62                           MARDIS (1-35)     1-35      PRATT (KS)
# 63                             MARDIS 2-35     2-35      PRATT (KS)
# 64                         MARDIS 'G'CHECK     1-35      PRATT (KS)
# 65                         MARDIS 'F'CHECK     1-35      PRATT (KS)
# 66                             MARDIS UNIT     1-35      PRATT (KS)
# 67                              MONTGOMERY        1      PRATT (KS)
# 68  no active wells found in 0.5 mi radius      NaN     BORDEN (TX)
# 69  no active wells found in 0.5 mi radius      NaN      RAINS (TX)
# 70  no active wells found in 0.5 mi radius      NaN      RAINS (TX)
# 71  no active wells found in 0.5 mi radius      NaN      RAINS (TX)
# 72                  HUNTER, LARRY T. ET AL        2       WEBB (TX)
# 73               VT HUNTER, LARRY T. ET AL        1       WEBB (TX)
# 74             LEYENDECKER HUNTER "D" 1375        6       WEBB (TX)
#
#                      Reservoir ProdType ProdStatus DrillType       TD  ...  \
# 0       MISENER SAND,MISS LIME      OIL     ACTIVE         V   3804.0  ...
# 1   RED FORK,PRUE,SKINNER,MISS      OIL     ACTIVE         V   4164.0  ...
# 2       MISENER SAND,MISS LIME      OIL     ACTIVE         V   3940.0  ...
# 3                         PRUE      OIL     ACTIVE         V   3910.0  ...
# 4       MISENER SAND,MISS LIME      OIL     ACTIVE         V   3804.0  ...
# 5   RED FORK,PRUE,SKINNER,MISS      OIL     ACTIVE         V   4164.0  ...
# 6       MISENER SAND,MISS LIME      OIL     ACTIVE         V   3940.0  ...
# 7                         None      OIL     ACTIVE         V   3950.0  ...
# 8                         PRUE      OIL     ACTIVE         V   3910.0  ...
# 9       MISENER SAND,MISS LIME      OIL     ACTIVE         V   3804.0  ...
# 10  RED FORK,PRUE,SKINNER,MISS      OIL     ACTIVE         V   3645.0  ...
# 11      MISENER SAND,MISS LIME      OIL     ACTIVE         V   3940.0  ...
# 12                        None      OIL     ACTIVE         V   3950.0  ...
# 13                        PRUE      OIL     ACTIVE         V   3910.0  ...
# 14      MISENER SAND,MISS LIME      OIL     ACTIVE         V   3804.0  ...
# 15  RED FORK,PRUE,SKINNER,MISS      OIL     ACTIVE         V   4164.0  ...
# 16      MISENER SAND,MISS LIME      OIL     ACTIVE         V   3940.0  ...
# 17                        None      OIL     ACTIVE         V   3950.0  ...
# 18                        PRUE      OIL     ACTIVE         V   3910.0  ...
# 19                         NaN      NaN        NaN       NaN      NaN  ...
# 20                 TRAVIS PEAK      GAS     ACTIVE         V   6450.0  ...
# 21                 HAYNESVILLE      GAS     ACTIVE         H  20638.0  ...
# 22                 HAYNESVILLE      GAS     ACTIVE         H  20960.0  ...
# 23                 HAYNESVILLE      GAS     ACTIVE         H  20818.0  ...
# 24                 HAYNESVILLE      GAS     ACTIVE         H  20442.0  ...
# 25                        FRED      OIL     ACTIVE         H   5845.0  ...
# 26                 HAYNESVILLE      GAS     ACTIVE         H  20825.0  ...
# 27                 HAYNESVILLE      GAS     ACTIVE         H  20790.0  ...
# 28                      WILCOX      OIL     ACTIVE         U   4150.0  ...
# 29                   WILCOX A3      OIL     ACTIVE         U   5000.0  ...
# ..                         ...      ...        ...       ...      ...  ...
# 45                   WILCOX D2      OIL     ACTIVE         U   5000.0  ...
# 46                    WILCOX C      OIL     ACTIVE         U   4250.0  ...
# 47                  WILCOX G-1      OIL     ACTIVE         U   4416.0  ...
# 48                 TRAVIS PEAK      GAS     ACTIVE         V   6500.0  ...
# 49                 HAYNESVILLE      GAS     ACTIVE         H  20638.0  ...
# 50                 HAYNESVILLE      GAS     ACTIVE         H  20818.0  ...
# 51                 HAYNESVILLE      GAS     ACTIVE         H  20442.0  ...
# 52                        FRED      OIL     ACTIVE         H   5845.0  ...
# 53                 HAYNESVILLE      GAS     ACTIVE         H  20790.0  ...
# 54                         NaN      NaN        NaN       NaN      NaN  ...
# 55                         NaN      NaN        NaN       NaN      NaN  ...
# 56        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4545.0  ...
# 57        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4311.0  ...
# 58        MISSISSIPPIAN SYSTEM      GAS     ACTIVE         U   4382.0  ...
# 59        MISSISSIPPIAN SYSTEM      GAS     ACTIVE         U   4360.0  ...
# 60        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4600.0  ...
# 61        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4280.0  ...
# 62        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4545.0  ...
# 63        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4311.0  ...
# 64        MISSISSIPPIAN SYSTEM      GAS     ACTIVE         U   4382.0  ...
# 65        MISSISSIPPIAN SYSTEM      GAS     ACTIVE         U   4360.0  ...
# 66        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4600.0  ...
# 67        MISSISSIPPIAN SYSTEM      OIL     ACTIVE         U   4280.0  ...
# 68                         NaN      NaN        NaN       NaN      NaN  ...
# 69                         NaN      NaN        NaN       NaN      NaN  ...
# 70                         NaN      NaN        NaN       NaN      NaN  ...
# 71                         NaN      NaN        NaN       NaN      NaN  ...
# 72                       OLMOS      GAS     ACTIVE         V   7275.0  ...
# 73                       OLMOS      GAS     ACTIVE         V   7220.0  ...
# 74                       OLMOS      GAS     ACTIVE         V   7509.0  ...
#
#    FulLqBFac FulGsEURMo FulGasBFac         OtherNo  \
# 0       1.99       88.0       1.51  11905524400000
# 1       0.26      161.0       1.69  11902114900371
# 2       2.00       88.0       1.51  11905524400000
# 3       1.94      166.0       1.69  11902780700000
# 4       1.99       88.0       1.51  11905524400000
# 5       0.26      161.0       1.69  11902114900371
# 6       2.00       88.0       1.51  11905524400000
# 7       1.27      381.0       1.52  11902780700000
# 8       1.94      166.0       1.69  11902780700000
# 9       1.99       88.0       1.51  11905524400000
# 10      1.76      380.0       1.69  11902114900371
# 11      2.00       88.0       1.51  11905524400000
# 12      1.27      381.0       1.52  11902780700000
# 13      1.94      166.0       1.69  11902780700000
# 14      1.99       88.0       1.51  11905524400000
# 15      0.26      161.0       1.69  11902114900371
# 16      2.00       88.0       1.51  11905524400000
# 17      1.27      381.0       1.52  11902780700000
# 18      1.94      166.0       1.69  11902780700000
# 19       NaN        NaN        NaN             NaN
# 20      1.62      300.0       1.95          219318
# 21      0.00      556.0       1.83          250285
# 22      0.00      581.0       1.00          251612
# 23      0.00      566.0       1.99          251003
# 24      0.00      556.0       1.88          250284
# 25      1.60        0.0       0.00          248184
# 26      0.00      581.0       1.00          251613
# 27      0.00      566.0       2.00          251270
# 28      1.37        0.0       0.00          207389
# 29      0.18      186.0       0.36          205486
# ..       ...        ...        ...             ...
# 45      0.60      188.0       0.65          205947
# 46      2.00        0.0       0.00          218511
# 47      0.71      188.0       1.04          205858
# 48      2.00      298.0       0.95          219319
# 49      0.00      556.0       1.83          250285
# 50      0.00      566.0       1.99          251003
# 51      0.00      556.0       1.88          250284
# 52      1.60        0.0       0.00          248184
# 53      0.00      566.0       2.00          251270
# 54       NaN        NaN        NaN             NaN
# 55       NaN        NaN        NaN             NaN
# 56       NaN        NaN        NaN               0
# 57       NaN        NaN        NaN               0
# 58       NaN        NaN        NaN               0
# 59       NaN        NaN        NaN               0
# 60       NaN        NaN        NaN               0
# 61       NaN        NaN        NaN               0
# 62       NaN        NaN        NaN               0
# 63       NaN        NaN        NaN               0
# 64       NaN        NaN        NaN               0
# 65       NaN        NaN        NaN               0
# 66       NaN        NaN        NaN               0
# 67       NaN        NaN        NaN               0
# 68       NaN        NaN        NaN             NaN
# 69       NaN        NaN        NaN             NaN
# 70       NaN        NaN        NaN             NaN
# 71       NaN        NaN        NaN             NaN
# 72      1.40      167.0       1.40               0
# 73      1.12      176.0       1.83            2583
# 74      1.40      401.0       1.33            5562
#
#                            geometry  Reference Inactive API  \
# 0   POINT (1235260.589 4023024.078)          35119227310000
# 1   POINT (1235871.294 4023615.964)          35119227310000
# 2   POINT (1235184.467 4023424.147)          35119227310000
# 3   POINT (1235453.446 4022844.164)          35119227310000
# 4   POINT (1235260.589 4023024.078)          35119226530000
# 5   POINT (1235871.294 4023615.964)          35119226530000
# 6   POINT (1235184.467 4023424.147)          35119226530000
# 7   POINT (1235672.356 4022660.054)          35119226530000
# 8   POINT (1235453.446 4022844.164)          35119226530000
# 9   POINT (1235260.589 4023024.078)          35119225680000
# 10  POINT (1236052.751 4022971.750)          35119225680000
# 11  POINT (1235184.467 4023424.147)          35119225680000
# 12  POINT (1235672.356 4022660.054)          35119225680000
# 13  POINT (1235453.446 4022844.164)          35119225680000
# 14  POINT (1235260.589 4023024.078)          35119224510000
# 15  POINT (1235871.294 4023615.964)          35119224510000
# 16  POINT (1235184.467 4023424.147)          35119224510000
# 17  POINT (1235672.356 4022660.054)          35119224510000
# 18  POINT (1235453.446 4022844.164)          35119224510000
# 19                             None          17113208680000
# 20  POINT (1534030.605 3640872.584)          17017308930000
# 21  POINT (1533609.787 3641497.185)          17017308930000
# 22  POINT (1534100.551 3641607.797)          17017308930000
# 23  POINT (1533136.390 3641421.657)          17017308930000
# 24  POINT (1533615.874 3641497.501)          17017308930000
# 25  POINT (1533644.888 3640820.948)          17017308930000
# 26  POINT (1534095.293 3641607.251)          17017308930000
# 27  POINT (1533142.541 3641421.347)          17017308930000
# 28  POINT (1724102.939 3569717.195)          17059239480000
# 29  POINT (1724256.800 3569166.610)          17059239480000
# ..                              ...                     ...
# 45  POINT (1724238.817 3569312.946)          17059239470000
# 46  POINT (1724032.174 3569824.449)          17059239470000
# 47  POINT (1724266.403 3569086.500)          17059239470000
# 48  POINT (1533002.895 3640660.795)          17017309440000
# 49  POINT (1533609.787 3641497.185)          17017309440000
# 50  POINT (1533136.390 3641421.657)          17017309440000
# 51  POINT (1533615.874 3641497.501)          17017309440000
# 52  POINT (1533644.888 3640820.948)          17017309440000
# 53  POINT (1533142.541 3641421.347)          17017309440000
# 54                             None          17113208680000
# 55                             None          17113207450000
# 56  POINT (1064234.589 4197007.221)          15151221060000
# 57  POINT (1064250.873 4196807.434)          15151221060000
# 58  POINT (1064044.255 4196401.251)          15151221060000
# 59  POINT (1063591.347 4196561.352)          15151221060000
# 60  POINT (1063561.033 4196355.982)          15151221060000
# 61  POINT (1064274.563 4196202.705)          15151221060000
# 62  POINT (1064234.589 4197007.221)          15151221060000
# 63  POINT (1064250.873 4196807.434)          15151221060000
# 64  POINT (1064044.255 4196401.251)          15151221060000
# 65  POINT (1063591.347 4196561.352)          15151221060000
# 66  POINT (1063561.033 4196355.982)          15151221060000
# 67  POINT (1064274.563 4196202.705)          15151221060000
# 68                             None          42033311010000
# 69                             None          42379301250000
# 70                             None          42379301190000
# 71                             None          42379301140000
# 72  POINT (1043672.992 3121836.256)          42479346910000
# 73  POINT (1043644.503 3122205.253)          42479346910000
# 74  POINT (1044276.897 3121489.460)          42479346910000
#
#           Reference Inactive Well Name  \
# 0                            LOZIER 13
# 1                            LOZIER 13
# 2                            LOZIER 13
# 3                            LOZIER 13
# 4                     LOZIER (TWIN) 12
# 5                     LOZIER (TWIN) 12
# 6                     LOZIER (TWIN) 12
# 7                     LOZIER (TWIN) 12
# 8                     LOZIER (TWIN) 12
# 9                     LOZIER (TWIN) 11
# 10                    LOZIER (TWIN) 11
# 11                    LOZIER (TWIN) 11
# 12                    LOZIER (TWIN) 11
# 13                    LOZIER (TWIN) 11
# 14         DANA-LOZIER (LOZIER #10) 10
# 15         DANA-LOZIER (LOZIER #10) 10
# 16         DANA-LOZIER (LOZIER #10) 10
# 17         DANA-LOZIER (LOZIER #10) 10
# 18         DANA-LOZIER (LOZIER #10) 10
# 19                   SAGRERA HEIRS 001
# 20                  TP SU68;WRIGHT 001
# 21                  TP SU68;WRIGHT 001
# 22                  TP SU68;WRIGHT 001
# 23                  TP SU68;WRIGHT 001
# 24                  TP SU68;WRIGHT 001
# 25                  TP SU68;WRIGHT 001
# 26                  TP SU68;WRIGHT 001
# 27                  TP SU68;WRIGHT 001
# 28            WX E RB SU6;KAUFFMAN 005
# 29            WX E RB SU6;KAUFFMAN 005
# ..                                 ...
# 45            WX G RB SU6;KAUFFMAN 004
# 46            WX G RB SU6;KAUFFMAN 004
# 47            WX G RB SU6;KAUFFMAN 004
# 48         TP SU68;KIRKPATRICK 001-ALT
# 49         TP SU68;KIRKPATRICK 001-ALT
# 50         TP SU68;KIRKPATRICK 001-ALT
# 51         TP SU68;KIRKPATRICK 001-ALT
# 52         TP SU68;KIRKPATRICK 001-ALT
# 53         TP SU68;KIRKPATRICK 001-ALT
# 54     CRIS 8 RB SUA;SAGRERA HEIRS 001
# 55  13400 RC SUA;SAGRERA HEIRS-KTM 001
# 56                   MARDIS I 1-35 135
# 57                   MARDIS I 1-35 135
# 58                   MARDIS I 1-35 135
# 59                   MARDIS I 1-35 135
# 60                   MARDIS I 1-35 135
# 61                   MARDIS I 1-35 135
# 62                 MARDIS "I" 1-35 135
# 63                 MARDIS "I" 1-35 135
# 64                 MARDIS "I" 1-35 135
# 65                 MARDIS "I" 1-35 135
# 66                 MARDIS "I" 1-35 135
# 67                 MARDIS "I" 1-35 135
# 68                       GRIFFIN "E" 1
# 69                       JENKINS "C" 1
# 70                THREE "J" RANCH 272A
# 71                        JENKINS 272A
# 72                     HUNTER - KONE 4
# 73                     HUNTER - KONE 4
# 74                     HUNTER - KONE 4
#
#     Reference Inactive Well Last Prod Date  \
# 0                               2001-12-01
# 1                               2001-12-01
# 2                               2001-12-01
# 3                               2001-12-01
# 4                               2001-12-01
# 5                               2001-12-01
# 6                               2001-12-01
# 7                               2001-12-01
# 8                               2001-12-01
# 9                               2001-12-01
# 10                              2001-12-01
# 11                              2001-12-01
# 12                              2001-12-01
# 13                              2001-12-01
# 14                              2001-12-01
# 15                              2001-12-01
# 16                              2001-12-01
# 17                              2001-12-01
# 18                              2001-12-01
# 19                              2001-09-01
# 20                              2008-11-01
# 21                              2008-11-01
# 22                              2008-11-01
# 23                              2008-11-01
# 24                              2008-11-01
# 25                              2008-11-01
# 26                              2008-11-01
# 27                              2008-11-01
# 28                              1996-06-01
# 29                              1996-06-01
# ..                                     ...
# 45                              1990-07-01
# 46                              1990-07-01
# 47                              1990-07-01
# 48                              1996-08-01
# 49                              1996-08-01
# 50                              1996-08-01
# 51                              1996-08-01
# 52                              1996-08-01
# 53                              1996-08-01
# 54                              2006-10-01
# 55                              2008-05-01
# 56                              2016-08-01
# 57                              2016-08-01
# 58                              2016-08-01
# 59                              2016-08-01
# 60                              2016-08-01
# 61                              2016-08-01
# 62                              2003-08-01
# 63                              2003-08-01
# 64                              2003-08-01
# 65                              2003-08-01
# 66                              2003-08-01
# 67                              2003-08-01
# 68                              1993-06-01
# 69                              1999-02-01
# 70                              2000-01-01
# 71                              2016-03-01
# 72                              2014-03-01
# 73                              2014-03-01
# 74                              2014-03-01
#
#                      Active Well Name & Number  MinFrstPrdDate
# 0                                     LOZIER 2      1979-01-01
# 1                               STATE PENNEY 4      1985-02-01
# 2                                     LOZIER 1      1979-01-01
# 3                              BUTCHER-JAMES 4      1985-06-01
# 4                                     LOZIER 2      1979-01-01
# 5                               STATE PENNEY 4      1985-02-01
# 6                                     LOZIER 1      1979-01-01
# 7                              BUTCHER-JAMES 2      1970-01-01
# 8                              BUTCHER-JAMES 4      1985-06-01
# 9                                     LOZIER 2      1979-01-01
# 10                                   BUTCHER 1      1970-01-01
# 11                                    LOZIER 1      1979-01-01
# 12                             BUTCHER-JAMES 2      1970-01-01
# 13                             BUTCHER-JAMES 4      1985-06-01
# 14                                    LOZIER 2      1979-01-01
# 15                              STATE PENNEY 4      1985-02-01
# 16                                    LOZIER 1      1979-01-01
# 17                             BUTCHER-JAMES 2      1970-01-01
# 18                             BUTCHER-JAMES 4      1985-06-01
# 19  no active wells found in 0.5 mi radius nan             NaN
# 20           TP SU68;B J JOHNSON HEIRS 001-ALT      1996-10-01
# 21       HA RA SU108;FLOURNOY 29-20 HC 002-ALT      2018-02-01
# 22          HA RA SU108;AGURS 29-20 HC 001-ALT      2020-03-01
# 23          HA RA SU108;ABNEY 30-19 HC 002-ALT      2018-12-01
# 24       HA RA SU108;FLOURNOY 29-20 HC 001-ALT      2018-02-01
# 25                   FRED VUB;JOHNSON 32 H 001      2014-12-01
# 26          HA RA SU108;AGURS 29-20 HC 002-ALT      2020-03-01
# 27          HA RA SU108;ABNEY 30-19 HC 003-ALT      2018-12-01
# 28                    WX F RB SU6;KAUFFMAN 006      1987-12-01
# 29                 WX A2 RF SUA;COON ET AL 006      1987-04-01
# ..                                         ...             ...
# 45                  WX D2 RF SUA;COON ETAL 009      1987-06-01
# 46                    WX C RB SU6;KAUFFMAN 003      1996-02-01
# 47                 WX F1 RF SUA;COON ET AL 008      1987-06-01
# 48            TP SU68;JOHN ABNEY HEIRS 001-ALT      1996-08-01
# 49       HA RA SU108;FLOURNOY 29-20 HC 002-ALT      2018-02-01
# 50          HA RA SU108;ABNEY 30-19 HC 002-ALT      2018-12-01
# 51       HA RA SU108;FLOURNOY 29-20 HC 001-ALT      2018-02-01
# 52                   FRED VUB;JOHNSON 32 H 001      2014-12-01
# 53          HA RA SU108;ABNEY 30-19 HC 003-ALT      2018-12-01
# 54  no active wells found in 0.5 mi radius nan             NaN
# 55  no active wells found in 0.5 mi radius nan             NaN
# 56                          MARDIS (1-35) 1-35      1986-04-01
# 57                            MARDIS 2-35 2-35      1987-11-01
# 58                        MARDIS 'G'CHECK 1-35      1988-02-01
# 59                        MARDIS 'F'CHECK 1-35      1988-02-01
# 60                            MARDIS UNIT 1-35      1988-02-01
# 61                                MONTGOMERY 1      1988-09-01
# 62                          MARDIS (1-35) 1-35      1986-04-01
# 63                            MARDIS 2-35 2-35      1987-11-01
# 64                        MARDIS 'G'CHECK 1-35      1988-02-01
# 65                        MARDIS 'F'CHECK 1-35      1988-02-01
# 66                            MARDIS UNIT 1-35      1988-02-01
# 67                                MONTGOMERY 1      1988-09-01
# 68  no active wells found in 0.5 mi radius nan             NaN
# 69  no active wells found in 0.5 mi radius nan             NaN
# 70  no active wells found in 0.5 mi radius nan             NaN
# 71  no active wells found in 0.5 mi radius nan             NaN
# 72                    HUNTER, LARRY T. ET AL 2      1985-09-01
# 73                 VT HUNTER, LARRY T. ET AL 1      1986-06-01
# 74               LEYENDECKER HUNTER "D" 1375 6      2005-03-01
#
# [75 rows x 129 columns]

# %% [markdown]
# ###  Create Function to Get Time Difference and See if Wells that Are Active Could've Held Well/Lease based on relativety to last production date

# %%
def withinOneYear(min_first_prod, last_prod_inactivewell, refwellaname):
    '''
    min_first_prod: earliest first prod date of active well
    last_prod_inactivewell: last prod date of inactive well
    refwellname: name of inactive well
    return: string to tell whether or not well started prod within 1 year of inactive well going offline
    
    '''
    
    #try to convert value to datetime - prevents error if there is not string date in row
    try:
        min_first_prod = dt.datetime.strptime(min_first_prod, "%Y-%m-%d")
        last_prod_inactivewell = dt.datetime.strptime(last_prod_inactivewell, "%Y-%m-%d")
    except:
        return "Not Applicable - No active Wells in 0.5 mi radius"
        
        
    #subtracting 2 dates to get difference of days
    deltaT = min_first_prod - last_prod_inactivewell
    
    if deltaT.days <=365:
        return f'Well began producing before or within 1 year of {refwellaname} going offline on {last_prod_inactivewell.date()}'
    else:
        return f"Well did NOT begin producing within 1 year of {refwellaname} last producing, which was {last_prod_inactivewell.date()}"
    
    
    
    
def IswithinOneYear(min_first_prod, last_prod_inactivewell, refwellaname):
    '''
    min_first_prod: earliest first prod date of active well
    last_prod_inactivewell: last prod date of inactive well
    refwellname: name of inactive well
    return: Boolean value of whether well started producing within 1 year or not
    '''

    #try to convert value to datetime - prevents error if there is not string date in row
    try:
        min_first_prod = dt.datetime.strptime(min_first_prod, "%Y-%m-%d")
        last_prod_inactivewell = dt.datetime.strptime(last_prod_inactivewell, "%Y-%m-%d")
    except:
        return "Not Applicable - No active Wells in 0.5 mi radius"


    #subtracting 2 dates to get difference of days
    deltaT = min_first_prod - last_prod_inactivewell

    if deltaT.days <=365:
        return True
    else:
        return False

# %% [markdown]
# #### Previewing Function Results

# %%
hbpwells["Well Active within 1 Year of Last Prod Date"] = hbpwells.apply(lambda x: withinOneYear(x['MinFrstPrdDate'], x['Reference Inactive Well Last Prod Date'], x["Reference Inactive Well Name"]), axis = 1)
hbpwells["Well Potentially HBP Lease?"] = hbpwells.apply(lambda x: IswithinOneYear(x['MinFrstPrdDate'], x['Reference Inactive Well Last Prod Date'], x["Reference Inactive Well Name"]), axis = 1)

hbpwells.head()
# Out:
#            APIUWI              OpAlias      LeaseName WellNo      County  \
# 0  35119209100000  STACY OPERATING LLC         LOZIER      2  PAYNE (OK)
# 1  35119225880000  STACY OPERATING LLC   STATE PENNEY      4  PAYNE (OK)
# 2  35119208510000  STACY OPERATING LLC         LOZIER      1  PAYNE (OK)
# 3  35119225810000  STACY OPERATING LLC  BUTCHER-JAMES      4  PAYNE (OK)
# 4  35119209100000  STACY OPERATING LLC         LOZIER      2  PAYNE (OK)
#
#                     Reservoir ProdType ProdStatus DrillType      TD  ...  \
# 0      MISENER SAND,MISS LIME      OIL     ACTIVE         V  3804.0  ...
# 1  RED FORK,PRUE,SKINNER,MISS      OIL     ACTIVE         V  4164.0  ...
# 2      MISENER SAND,MISS LIME      OIL     ACTIVE         V  3940.0  ...
# 3                        PRUE      OIL     ACTIVE         V  3910.0  ...
# 4      MISENER SAND,MISS LIME      OIL     ACTIVE         V  3804.0  ...
#
#   FulGasBFac         OtherNo                         geometry  \
# 0       1.51  11905524400000  POINT (1235260.589 4023024.078)
# 1       1.69  11902114900371  POINT (1235871.294 4023615.964)
# 2       1.51  11905524400000  POINT (1235184.467 4023424.147)
# 3       1.69  11902780700000  POINT (1235453.446 4022844.164)
# 4       1.51  11905524400000  POINT (1235260.589 4023024.078)
#
#   Reference Inactive API  Reference Inactive Well Name  \
# 0         35119227310000                     LOZIER 13
# 1         35119227310000                     LOZIER 13
# 2         35119227310000                     LOZIER 13
# 3         35119227310000                     LOZIER 13
# 4         35119226530000              LOZIER (TWIN) 12
#
#    Reference Inactive Well Last Prod Date  Active Well Name & Number  \
# 0                              2001-12-01                   LOZIER 2
# 1                              2001-12-01             STATE PENNEY 4
# 2                              2001-12-01                   LOZIER 1
# 3                              2001-12-01            BUTCHER-JAMES 4
# 4                              2001-12-01                   LOZIER 2
#
#    MinFrstPrdDate        Well Active within 1 Year of Last Prod Date  \
# 0      1979-01-01  Well began producing before or within 1 year o...
# 1      1985-02-01  Well began producing before or within 1 year o...
# 2      1979-01-01  Well began producing before or within 1 year o...
# 3      1985-06-01  Well began producing before or within 1 year o...
# 4      1979-01-01  Well began producing before or within 1 year o...
#
#    Well Potentially HBP Lease?
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                         True
#
# [5 rows x 131 columns]

# %% [markdown]
# # Exporting Table to File

# %%
hbpwells.to_excel("Output/Source Table - Potential HBP Wells.xlsx", index = False)

# %%
print(hbpwells.columns)
# Out:
# Index(['APIUWI', 'OpAlias', 'LeaseName', 'WellNo', 'County', 'Reservoir',
#        'ProdType', 'ProdStatus', 'DrillType', 'TD',
#        ...
#        'FulGasBFac', 'OtherNo', 'geometry', 'Reference Inactive API',
#        'Reference Inactive Well Name',
#        'Reference Inactive Well Last Prod Date', 'Active Well Name & Number',
#        'MinFrstPrdDate', 'Well Active within 1 Year of Last Prod Date',
#        'Well Potentially HBP Lease?'],
#       dtype='object', length=131)

# %%
abridgedCols = ['Reference Inactive API','Reference Inactive Well Name', 'Reference Inactive Well Last Prod Date', 'County', 'APIUWI', 'OpAlias', 'LeaseName', 'WellNo', "FstPrdDate", 'Well Active within 1 Year of Last Prod Date', 'Well Potentially HBP Lease?']

# %%
abridged = hbpwells[abridgedCols]

# %%
abridged.to_excel('Output/Abridged Table.xlsx', index = False, sheet_name = 'AbridgedTable')
